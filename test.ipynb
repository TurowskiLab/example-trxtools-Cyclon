# %%
import pandas as pd
df = pd.read_pickle("04_BigWig/temp_AG241010_Cyclon_none_120mJ_1_PROFILE_3end_fractionOFpolyA_fwd_chr21.pkl.gz",compression='gzip')
df
# Out:
#           fraction
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 46709978       NaN
# 46709979       NaN
# 46709980       NaN
# 46709981       NaN
# 46709982       NaN
#
# [46709983 rows x 1 columns]
